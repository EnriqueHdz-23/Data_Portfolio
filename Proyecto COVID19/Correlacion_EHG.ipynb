# %%
import pandas as pd
import numpy as np 
df = pd.read_csv('datos_abiertos_covid19.csv', nrows = 6200)

# %%
df.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0          2020-07-30      004228       2       3          25     2
# 1          2020-07-30      1e6804       2       4          27     1
# 2          2020-07-30      105b61       2       4          15     2
# 3          2020-07-30      093267       2       4           2     2
# 4          2020-07-30      008cc5       2       3          25     2
#
#    ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... CARDIOVASCULAR  \
# 0           25           25              6              1  ...              2
# 1           27           27              4              1  ...              2
# 2           15           15              9              1  ...              2
# 3            2            2              4              2  ...              2
# 4           25           25             18              2  ...              2
#
#   OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  RESULTADO  MIGRANTE  \
# ...

# %%
np.corrcoef([df['OBESIDAD'],df['SEXO'],df['TABAQUISMO']])
# Out:
# array([[1.        , 0.00545513, 0.92072609],
#        [0.00545513, 1.        , 0.00382255],
#        [0.92072609, 0.00382255, 1.        ]])

# %%
df.drop(inplace = True, columns = ['FECHA_ACTUALIZACION','ID_REGISTRO','PAIS_NACIONALIDAD'])

# %%
df.corr()
# Out:
#                     ORIGEN    SECTOR  ENTIDAD_UM      SEXO  ENTIDAD_NAC  \
# ORIGEN                 NaN       NaN         NaN       NaN          NaN
# SECTOR                 NaN  1.000000    0.009647 -0.004301     0.010320
# ENTIDAD_UM             NaN  0.009647    1.000000  0.019226     0.775415
# SEXO                   NaN -0.004301    0.019226  1.000000     0.014999
# ENTIDAD_NAC            NaN  0.010320    0.775415  0.014999     1.000000
# ENTIDAD_RES            NaN  0.009830    0.970991  0.020784     0.775611
# MUNICIPIO_RES          NaN  0.062934    0.354145 -0.001770     0.265558
# TIPO_PACIENTE          NaN -0.031262   -0.030573  0.123720    -0.005746
# INTUBADO               NaN  0.031157    0.030990 -0.124159     0.006114
# NEUMONIA               NaN  0.014248    0.076067 -0.105715     0.028985
# EDAD                   NaN -0.022224    0.008509  0.084741     0.032366
# NACIONALIDAD           NaN  0.001012   -0.017319 -0.001766     0.249549
# ...

# %%
df.drop(inplace = True, columns = ['RESULTADO','ORIGEN','MIGRANTE','PAIS_ORIGEN'])
corr = round(df.corr(),3)
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_b1ce1b62_e3dc_11ea_9d95_6df97d6dfe89row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_b1ce1b62_e3dc_11ea_9d95_6df97d6dfe89row0_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_b1ce1b62_e3dc_11ea_9d95_6df97d6dfe89row0_col2 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_b1ce1b62_e3dc_11ea_9d95_6df97d6dfe89row0_col3 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_b1ce1b62_e3dc_11ea_9d95_6df97d6dfe89row0_col4 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_b1ce1b62_e3dc_11ea_9d95_6df97d6dfe89row0_col5 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_b1ce1b62_e3dc_11ea_9d95_6df97d6dfe89row0_col6 {
#             background-color:  #79abd0;
#             color:  #000000;
# ...
